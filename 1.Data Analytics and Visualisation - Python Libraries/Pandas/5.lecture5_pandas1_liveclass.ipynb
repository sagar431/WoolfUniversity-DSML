# %% [markdown]
# # Agenda
#
# 1. Introduction to Pandas
# 2. DataFrame & Series
# 3. Creating DataFrame from Scratch (Post-read)
# 4. Basic ops on a DataFrame
# 5. Basic ops on Columns
#    - Accessing column(s)
#    - Check for unique values
#    - Rename column
#    - Deleting column(s)
#    - Creating new column(s)
# 5. Basic ops on Rows
#    - Implicit/Explicit index
#    - Indexing in Series
#    - Slicing in Series
#    - loc/iloc
#    - Indexing/Slicing in DataFrame

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Why pandas?

# %%
# NUMPY: homogeneous datatypes
# PANDAS: hetrogeneous datatypes

# %% [markdown]
# ## Problem Statement
#
# You are a DS at McKinsey
#
# - McKinsey wants to understand the relation between GDP per capita and life expectancy for their clients.

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2024-05-23 16:32:39--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 173.194.217.113, 173.194.217.100, 173.194.217.138, ...
# Connecting to drive.google.com (drive.google.com)|173.194.217.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download [following]
# --2024-05-23 16:32:39--  https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 173.194.217.132, 2607:f8b0:400c:c13::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|173.194.217.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [application/octet-stream]
# Saving to: ‘mckinsey.csv’
#
# ...

# %%
df = pd.read_csv('mckinsey.csv') # storing the data in df
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
# pandas is built on top of numpy

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %%
list(df["country"])
# Out:
# ['Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
# Top 5 rows

df.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
# Bottom 5 rows
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
# Shape of your DF

df.shape
# Out:
# (1704, 6)

# %% [markdown]
# ## DataFrame creation

# %%
# | Name      | Age  | Department  |
# |-----------|------|-------------|
# | Alice     | 25   | Marketing   |
# | Bob       | 32   | Engineering |
# | Charlie   | 28   | Sales       |
# | Denise    | 35   | Finance     |

# %% [markdown]
# ## Method 1: List

# %%
data = [
    ['Bob', 32, 'Engineering'],
    ['Charlie', 28, 'Sales'],
    ['Alice', 25, 'Marketing'],
    ['Denise', 35, 'Finance']
]

column_names = ['Name', 'Age', 'Department']

# %%
# df = pd.DataFrame(data, columns=column_names)
# df

# %% [markdown]
# ## Method 2: Dictionary

# %%
data = {
    'Name': np.array(['Alice', 'Bob', 'Charlie', 'Denise']),
    'Age': (25, 32, 28, 35),
    'Department': ('Marketing', 'Engineering', 'Sales',"")
}

# %%
pd.DataFrame(data)
# Out:
#       Name  Age   Department
# 0    Alice   25    Marketing
# 1      Bob   32  Engineering
# 2  Charlie   28        Sales
# 3   Denise   35

# %%
#NAN: not a number

# %% [markdown]
# ## Basic operations on Columns

# %%
# 1) Add a column
# 2) Delete a column
# 3) Renaming a column

# %%
df.columns # To print the column names
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df['country'].head() # accessing a single column
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df[['country', 'continent']].head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1  Afghanistan      Asia
# 2  Afghanistan      Asia
# 3  Afghanistan      Asia
# 4  Afghanistan      Asia

# %%
df[['country']].head()
# Out:
#        country
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan

# %%
df['country'].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df['country'].nunique()
# Out:
# 142

# %%
len(df['country'].unique())
# Out:
# 142

# %%
df['country'].value_counts()
# Out:
# country
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: count, Length: 142, dtype: int64

# %%
df['new_col'] = 1

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  new_col
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314        1
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030        1
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710        1
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138        1
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106        1

# %%
## Renaming of certain cols

df.rename(columns={"population": "Population", "country": "Country"})
# Out:
#           Country  year  Population continent  life_exp     gdp_cap  new_col
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314        1
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030        1
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710        1
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138        1
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106        1
# ...           ...   ...         ...       ...       ...         ...      ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306        1
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786        1
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960        1
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623        1
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298        1
#
# [1704 rows x 7 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  new_col
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314        1
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030        1
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710        1
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138        1
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106        1

# %%
df.rename(columns={"population": "Population", "country": "Country"}, inplace = True)

# %%
df.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap  new_col
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314        1
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030        1
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710        1
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138        1
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106        1

# %%
# trick solution

df.columns
# Out:
# Index(['Country', 'year', 'Population', 'continent', 'life_exp', 'gdp_cap',
#        'new_col'],
#       dtype='object')

# %%
new_col_names = ['Country', 'Year', 'Population', 'Continent', 'Life_Exp', 'GDP_cap','New_col']

# %%
df.columns = new_col_names

# %%
df.head()
# Out:
#        Country  Year  Population Continent  Life_Exp     GDP_cap  New_col
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314        1
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030        1
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710        1
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138        1
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106        1

# %%
df.drop('New_col', axis = 1)
# Out:
#           Country  Year  Population Continent  Life_Exp     GDP_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        Country  Year  Population Continent  Life_Exp     GDP_cap  New_col
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314        1
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030        1
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710        1
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138        1
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106        1

# %%
df.drop('New_col', axis = 1, inplace = True)

# %%
df.head()
# Out:
#        Country  Year  Population Continent  Life_Exp     GDP_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.drop('Continent', axis=1, inplace=True)

# %%
df["Year+7"] = df["Year"] + 7
df.head()
# Out:
#        Country  Year  Population  Life_Exp     GDP_cap  Year+7
# 0  Afghanistan  1952     8425333    28.801  779.445314    1959
# 1  Afghanistan  1957     9240934    30.332  820.853030    1964
# 2  Afghanistan  1962    10267083    31.997  853.100710    1969
# 3  Afghanistan  1967    11537966    34.020  836.197138    1974
# 4  Afghanistan  1972    13079460    36.088  739.981106    1979

# %%
df['gdp']=df['GDP_cap'] * df['Population']
df.head()
# Out:
#        Country  Year  Population  Life_Exp     GDP_cap  Year+7           gdp
# 0  Afghanistan  1952     8425333    28.801  779.445314    1959  6.567086e+09
# 1  Afghanistan  1957     9240934    30.332  820.853030    1964  7.585449e+09
# 2  Afghanistan  1962    10267083    31.997  853.100710    1969  8.758856e+09
# 3  Afghanistan  1967    11537966    34.020  836.197138    1974  9.648014e+09
# 4  Afghanistan  1972    13079460    36.088  739.981106    1979  9.678553e+09

# %%
df["Own"] = [i for i in range(df.shape[0])]  # count of these values should be correct
df.head()
# Out:
#        Country  Year  Population  Life_Exp     GDP_cap  Year+7           gdp  \
# 0  Afghanistan  1952     8425333    28.801  779.445314    1959  6.567086e+09
# 1  Afghanistan  1957     9240934    30.332  820.853030    1964  7.585449e+09
# 2  Afghanistan  1962    10267083    31.997  853.100710    1969  8.758856e+09
# 3  Afghanistan  1967    11537966    34.020  836.197138    1974  9.648014e+09
# 4  Afghanistan  1972    13079460    36.088  739.981106    1979  9.678553e+09
#
#    Own
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4

# %% [markdown]
# ## Quiz
#
# Given a dataframe consisting of 5 columns, which is the correct code to drop the 3rd column from the start?

# %%
df_quiz = df[['Country', 'Year',	'Population', 'Life_Exp'	,'GDP_cap']]
df_quiz.head()
# Out:
#        Country  Year  Population  Life_Exp     GDP_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df_quiz.columns[2]
# Out:
# 'Population'

# %%
df_quiz
# Out:
#           Country  Year  Population  Life_Exp     GDP_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df_quiz.drop(df_quiz.columns[-3], axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-174-dbe2bcd07e16> in <cell line: 1>()
# ----> 1 df_quiz.drop(df_quiz.columns[-3], axis=0)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %% [markdown]
# ## Basic operations on Rows

# %%
df.head()
# Out:
#        Country  Year  Population  Life_Exp     GDP_cap  Year+7           gdp  \
# 0  Afghanistan  1952     8425333    28.801  779.445314    1959  6.567086e+09
# 1  Afghanistan  1957     9240934    30.332  820.853030    1964  7.585449e+09
# 2  Afghanistan  1962    10267083    31.997  853.100710    1969  8.758856e+09
# 3  Afghanistan  1967    11537966    34.020  836.197138    1974  9.648014e+09
# 4  Afghanistan  1972    13079460    36.088  739.981106    1979  9.678553e+09
#
#    Own
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4

# %%
df.shape
# Out:
# (1704, 8)

# %%
df.tail()
# Out:
#        Country  Year  Population  Life_Exp     GDP_cap  Year+7           gdp  \
# 1699  Zimbabwe  1987     9216418    62.351  706.157306    1994  6.508241e+09
# 1700  Zimbabwe  1992    10704340    60.377  693.420786    1999  7.422612e+09
# 1701  Zimbabwe  1997    11404948    46.809  792.449960    2004  9.037851e+09
# 1702  Zimbabwe  2002    11926563    39.989  672.038623    2009  8.015111e+09
# 1703  Zimbabwe  2007    12311143    43.487  469.709298    2014  5.782658e+09
#
#        Own
# 1699  1699
# 1700  1700
# 1701  1701
# 1702  1702
# 1703  1703

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.index = list(range(1, df.shape[0]+1)) # create a list of indices of same length
df
# Out:
#           Country  Year  Population  Life_Exp     GDP_cap  Year+7  \
# 1     Afghanistan  1952     8425333    28.801  779.445314    1959
# 2     Afghanistan  1957     9240934    30.332  820.853030    1964
# 3     Afghanistan  1962    10267083    31.997  853.100710    1969
# 4     Afghanistan  1967    11537966    34.020  836.197138    1974
# 5     Afghanistan  1972    13079460    36.088  739.981106    1979
# ...           ...   ...         ...       ...         ...     ...
# 1700     Zimbabwe  1987     9216418    62.351  706.157306    1994
# 1701     Zimbabwe  1992    10704340    60.377  693.420786    1999
# 1702     Zimbabwe  1997    11404948    46.809  792.449960    2004
# 1703     Zimbabwe  2002    11926563    39.989  672.038623    2009
# 1704     Zimbabwe  2007    12311143    43.487  469.709298    2014
#
#                gdp   Own
# 1     6.567086e+09     0
# 2     7.585449e+09     1
# 3     8.758856e+09     2
# 4     9.648014e+09     3
# 5     9.678553e+09     4
# ...

# %%
# Explicit and Implicit Indices

# %%
df.index[1] # 1 is the implicit index and it returns the explicit index
# Out:
# 2

# %%
df.index = np.arange(1, df.shape[0]+1, dtype='float')
df
# Out:
#             Country  Year  Population  Life_Exp     GDP_cap  Year+7  \
# 1.0     Afghanistan  1952     8425333    28.801  779.445314    1959
# 2.0     Afghanistan  1957     9240934    30.332  820.853030    1964
# 3.0     Afghanistan  1962    10267083    31.997  853.100710    1969
# 4.0     Afghanistan  1967    11537966    34.020  836.197138    1974
# 5.0     Afghanistan  1972    13079460    36.088  739.981106    1979
# ...             ...   ...         ...       ...         ...     ...
# 1700.0     Zimbabwe  1987     9216418    62.351  706.157306    1994
# 1701.0     Zimbabwe  1992    10704340    60.377  693.420786    1999
# 1702.0     Zimbabwe  1997    11404948    46.809  792.449960    2004
# 1703.0     Zimbabwe  2002    11926563    39.989  672.038623    2009
# 1704.0     Zimbabwe  2007    12311143    43.487  469.709298    2014
#
#                  gdp   Own
# 1.0     6.567086e+09     0
# 2.0     7.585449e+09     1
# 3.0     8.758856e+09     2
# 4.0     9.648014e+09     3
# ...

# %%
df.index[1]
# Out:
# 2.0

# %%
sample = df.head()
sample
# Out:
#          Country  Year  Population  Life_Exp     GDP_cap  Year+7  \
# 1.0  Afghanistan  1952     8425333    28.801  779.445314    1959
# 2.0  Afghanistan  1957     9240934    30.332  820.853030    1964
# 3.0  Afghanistan  1962    10267083    31.997  853.100710    1969
# 4.0  Afghanistan  1967    11537966    34.020  836.197138    1974
# 5.0  Afghanistan  1972    13079460    36.088  739.981106    1979
#
#               gdp  Own
# 1.0  6.567086e+09    0
# 2.0  7.585449e+09    1
# 3.0  8.758856e+09    2
# 4.0  9.648014e+09    3
# 5.0  9.678553e+09    4

# %%
sample.index = ['a', 'b', 'c', 'd', 'e']
sample
# Out:
#        Country  Year  Population  Life_Exp     GDP_cap  Year+7           gdp  \
# a  Afghanistan  1952     8425333    28.801  779.445314    1959  6.567086e+09
# b  Afghanistan  1957     9240934    30.332  820.853030    1964  7.585449e+09
# c  Afghanistan  1962    10267083    31.997  853.100710    1969  8.758856e+09
# d  Afghanistan  1967    11537966    34.020  836.197138    1974  9.648014e+09
# e  Afghanistan  1972    13079460    36.088  739.981106    1979  9.678553e+09
#
#    Own
# a    0
# b    1
# c    2
# d    3
# e    4

# %%
sample.index[1]
# Out:
# 'b'

# %%
ser = df["Country"]
ser.head(20)
# Out:
# 1.0     Afghanistan
# 2.0     Afghanistan
# 3.0     Afghanistan
# 4.0     Afghanistan
# 5.0     Afghanistan
# 6.0     Afghanistan
# 7.0     Afghanistan
# 8.0     Afghanistan
# 9.0     Afghanistan
# 10.0    Afghanistan
# 11.0    Afghanistan
# 12.0    Afghanistan
# 13.0        Albania
# 14.0        Albania
# 15.0        Albania
# 16.0        Albania
# 17.0        Albania
# 18.0        Albania
# 19.0        Albania
# 20.0        Albania
# Name: Country, dtype: object

# %%
ser[12] # Indexing in Series used explicit indices
# Out:
# 'Afghanistan'

# %%
ser[13]
# Out:
# 'Albania'

# %% [markdown]
# What about accessing a subset of rows (say 6th to 15th)?

# %%
ser[5:15] # Slicing is working on based of implicit indexing
# Out:
# 5.0     Afghanistan
# 6.0     Afghanistan
# 7.0     Afghanistan
# 8.0     Afghanistan
# 9.0     Afghanistan
# 10.0    Afghanistan
# 11.0    Afghanistan
# 12.0    Afghanistan
# 13.0        Albania
# 14.0        Albania
# 15.0        Albania
# Name: Country, dtype: object

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df[5:15]
# Out:
#           Country  Year  Population  Life_Exp      GDP_cap  Year+7  \
# 5.0   Afghanistan  1972    13079460    36.088   739.981106    1979
# 6.0   Afghanistan  1977    14880372    38.438   786.113360    1984
# 7.0   Afghanistan  1982    12881816    39.854   978.011439    1989
# 8.0   Afghanistan  1987    13867957    40.822   852.395945    1994
# 9.0   Afghanistan  1992    16317921    41.674   649.341395    1999
# 10.0  Afghanistan  1997    22227415    41.763   635.341351    2004
# 11.0  Afghanistan  2002    25268405    42.129   726.734055    2009
# 12.0  Afghanistan  2007    31889923    43.828   974.580338    2014
# 13.0      Albania  1952     1282697    55.230  1601.056136    1959
# 14.0      Albania  1957     1476505    59.280  1942.284244    1964
# 15.0      Albania  1962     1728137    64.820  2312.888958    1969
#
#                gdp  Own
# 5.0   9.678553e+09    4
# 6.0   1.169766e+10    5
# 7.0   1.259856e+10    6
# 8.0   1.182099e+10    7
# 9.0   1.059590e+10    8
# ...

# %%
# iloc and loc

# %%
df.loc[1]
# Out:
# Country             Afghanistan
# Year                       1952
# Population              8425333
# Life_Exp                 28.801
# GDP_cap              779.445314
# Year+7                     1959
# gdp           6567086329.952229
# Own                           0
# Name: 1.0, dtype: object

# %%
df.head()
# Out:
#          Country  Year  Population  Life_Exp     GDP_cap  Year+7  \
# 1.0  Afghanistan  1952     8425333    28.801  779.445314    1959
# 2.0  Afghanistan  1957     9240934    30.332  820.853030    1964
# 3.0  Afghanistan  1962    10267083    31.997  853.100710    1969
# 4.0  Afghanistan  1967    11537966    34.020  836.197138    1974
# 5.0  Afghanistan  1972    13079460    36.088  739.981106    1979
#
#               gdp  Own
# 1.0  6.567086e+09    0
# 2.0  7.585449e+09    1
# 3.0  8.758856e+09    2
# 4.0  9.648014e+09    3
# 5.0  9.678553e+09    4

# %%
df.loc[1:3]
# Out:
#          Country  Year  Population  Life_Exp     GDP_cap  Year+7  \
# 1.0  Afghanistan  1952     8425333    28.801  779.445314    1959
# 2.0  Afghanistan  1957     9240934    30.332  820.853030    1964
# 3.0  Afghanistan  1962    10267083    31.997  853.100710    1969
#
#               gdp  Own
# 1.0  6.567086e+09    0
# 2.0  7.585449e+09    1
# 3.0  8.758856e+09    2

# %%
df.loc[1:10]
# Out:
#           Country  Year  Population  Life_Exp     GDP_cap  Year+7  \
# 1.0   Afghanistan  1952     8425333    28.801  779.445314    1959
# 2.0   Afghanistan  1957     9240934    30.332  820.853030    1964
# 3.0   Afghanistan  1962    10267083    31.997  853.100710    1969
# 4.0   Afghanistan  1967    11537966    34.020  836.197138    1974
# 5.0   Afghanistan  1972    13079460    36.088  739.981106    1979
# 6.0   Afghanistan  1977    14880372    38.438  786.113360    1984
# 7.0   Afghanistan  1982    12881816    39.854  978.011439    1989
# 8.0   Afghanistan  1987    13867957    40.822  852.395945    1994
# 9.0   Afghanistan  1992    16317921    41.674  649.341395    1999
# 10.0  Afghanistan  1997    22227415    41.763  635.341351    2004
#
#                gdp  Own
# 1.0   6.567086e+09    0
# 2.0   7.585449e+09    1
# 3.0   8.758856e+09    2
# 4.0   9.648014e+09    3
# 5.0   9.678553e+09    4
# 6.0   1.169766e+10    5
# 7.0   1.259856e+10    6
# 8.0   1.182099e+10    7
# ...

# %%
df_new2 = df.loc[1:3]
df_new2
# Out:
#          Country  Year  Population  Life_Exp     GDP_cap  Year+7  \
# 1.0  Afghanistan  1952     8425333    28.801  779.445314    1959
# 2.0  Afghanistan  1957     9240934    30.332  820.853030    1964
# 3.0  Afghanistan  1962    10267083    31.997  853.100710    1969
#
#               gdp  Own
# 1.0  6.567086e+09    0
# 2.0  7.585449e+09    1
# 3.0  8.758856e+09    2

# %%
df_new2.index = ['b','c','a']

# %%
df_new2
# Out:
#        Country  Year  Population  Life_Exp     GDP_cap  Year+7           gdp  \
# b  Afghanistan  1952     8425333    28.801  779.445314    1959  6.567086e+09
# c  Afghanistan  1957     9240934    30.332  820.853030    1964  7.585449e+09
# a  Afghanistan  1962    10267083    31.997  853.100710    1969  8.758856e+09
#
#    Own
# b    0
# c    1
# a    2

# %%
df_new2.loc['a':'b']
# Out:
# Empty DataFrame
# Columns: [Country, Year, Population, Life_Exp, GDP_cap, Year+7, gdp, Own]
# Index: []

# %% [markdown]
# ## Quiz

# %%
demo = pd.Series(['a','b','c','d','e'], index=[1,5,3,7,3])

# %%
demo
# Out:
# 1    a
# 5    b
# 3    c
# 7    d
# 3    e
# dtype: object

# %%
demo.loc[1:3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-222-3982b77eccbc> in <cell line: 1>()
# ----> 1 demo.loc[1:3]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1101
#    1102             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103             return self._getitem_axis(maybe_callable, axis=axis)
#    1104
#    1105     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1321         if isinstance(key, slice):
#    1322             self._validate_key(key, axis)
# -> 1323             return self._get_slice_axis(key, axis=axis)
#    1324         elif com.is_bool_indexer(key):
#    1325             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
df.loc[9::-3]
# Out:
#          Country  Year  Population  Life_Exp     GDP_cap  Year+7  \
# 9.0  Afghanistan  1992    16317921    41.674  649.341395    1999
# 6.0  Afghanistan  1977    14880372    38.438  786.113360    1984
# 3.0  Afghanistan  1962    10267083    31.997  853.100710    1969
#
#               gdp  Own
# 9.0  1.059590e+10    8
# 6.0  1.169766e+10    5
# 3.0  8.758856e+09    2

# %%
a = [1,2,4,5,6]

a[::-3]
# Out:
# [6, 2]

# %% [markdown]
# ## iloc

# %%
df.iloc[1]
# Out:
# Country             Afghanistan
# Year                       1957
# Population              9240934
# Life_Exp                 30.332
# GDP_cap               820.85303
# Year+7                     1964
# gdp           7585448670.233646
# Own                           1
# Name: 2.0, dtype: object

# %%
df.iloc[0:2]
# Out:
#          Country  Year  Population  Life_Exp     GDP_cap  Year+7  \
# 1.0  Afghanistan  1952     8425333    28.801  779.445314    1959
# 2.0  Afghanistan  1957     9240934    30.332  820.853030    1964
#
#               gdp  Own
# 1.0  6.567086e+09    0
# 2.0  7.585449e+09    1

# %%
# iloc works with implicit Python-style indices and last element is exculsive

# %%
df.iloc[[1, 10, 100]]
# Out:
#            Country  Year  Population  Life_Exp     GDP_cap  Year+7  \
# 2.0    Afghanistan  1957     9240934    30.332  820.853030    1964
# 11.0   Afghanistan  2002    25268405    42.129  726.734055    2009
# 101.0   Bangladesh  1972    70759295    45.252  630.233627    1979
#
#                 gdp  Own
# 2.0    7.585449e+09    1
# 11.0   1.836341e+10   10
# 101.0  4.459489e+10  100

# %% [markdown]
# ## difference between iloc and loc

# %%
df.iloc[-1] # last record # iloc works with positinal indices
# Out:
# Country                Zimbabwe
# Year                       2007
# Population             12311143
# Life_Exp                 43.487
# GDP_cap              469.709298
# Year+7                     2014
# gdp           5782658337.338729
# Own                        1703
# Name: 1704.0, dtype: object

# %%
df.loc[-1] #loc works with assigned labels
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# KeyError: -1.0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ## How to access both rows and cols together

# %%
df.iloc[1:10, 1:3] #implicit
# Out:
#       Year  Population
# 2.0   1957     9240934
# 3.0   1962    10267083
# 4.0   1967    11537966
# 5.0   1972    13079460
# 6.0   1977    14880372
# 7.0   1982    12881816
# 8.0   1987    13867957
# 9.0   1992    16317921
# 10.0  1997    22227415

# %%
df.loc[1:10, 'Year': 'Population'] #explicit
# Out:
#       Year  Population
# 1.0   1952     8425333
# 2.0   1957     9240934
# 3.0   1962    10267083
# 4.0   1967    11537966
# 5.0   1972    13079460
# 6.0   1977    14880372
# 7.0   1982    12881816
# 8.0   1987    13867957
# 9.0   1992    16317921
# 10.0  1997    22227415

# %%
# How to select records from 30th to 40th row for the last 3 columns using iloc?

# %%
df.iloc[29:40, -3:]
# Out:
#       Year+7           gdp  Own
# 30.0    1984  8.422742e+10   29
# 31.0    1989  1.150971e+11   30
# 32.0    1994  1.321197e+11   31
# 33.0    1999  1.321024e+11   32
# 34.0    2004  1.394670e+11   33
# 35.0    2009  1.654477e+11   34
# 36.0    2014  2.074449e+11   35
# 37.0    1959  1.489956e+10   36
# 38.0    1964  1.746062e+10   37
# 39.0    1969  2.060359e+10   38
# 40.0    1974  2.898060e+10   39
